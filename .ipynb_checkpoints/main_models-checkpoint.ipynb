# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, PolynomialFeatures
from keras.preprocessing.sequence import TimeseriesGenerator
from tensorflow.keras.utils import load_img, img_to_array, array_to_img
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf

from keras.models import Sequential, Model
from keras.regularizers import L1L2
from keras.layers import *
from keras.callbacks import TensorBoard, ReduceLROnPlateau, ModelCheckpoint, EarlyStopping
from keras.optimizers import *
from keras import initializers
from keras import backend as K
from keras.layers import LSTM, InputLayer, Dense, Input, Flatten, concatenate, Reshape
from keras.callbacks import EarlyStopping
from random import randint
import pickle
import glob
import PIL

def rmse(y_true,y_pred):
    return np.sqrt(np.mean(np.square(y_pred-y_true)))

def mape(y_true, y_pred):
    mask = y_true != 0  # Create a mask for non-zero true values
    return np.mean(np.abs((y_true[mask] - y_pred[mask]) / y_true[mask]))

def smape(y_true, y_pred):
    numerator = np.abs(y_pred - y_true)
    denominator = (np.abs(y_true) + np.abs(y_pred)) / 2
    return np.mean(np.divide(numerator, denominator))

def getTT(region):
    return round((((region-100)//50) * -5.2222 ) + 147.11),round((((region%50)-2) * 5.2083)+20.458 )

def mean_absolute_percentage_error_revise(y_true, y_pred):
    # RMSE
    rmse = K.sqrt(K.mean(K.square(y_pred - y_true)))

    # SMAPE
    epsilon = 1e-10  # Small constant to avoid division by zero
    smape_numerator = tf.abs(y_true - y_pred)
    smape_denominator = tf.maximum(tf.abs(y_true) + tf.abs(y_pred), epsilon)
    smape = K.mean(smape_numerator / smape_denominator)

    alpha = 0.5 # hyperparameter, adjust alpha as needed
    combined_loss = alpha * rmse + (1 - alpha) * smape

    return combined_loss
def custom_metric(y_true, y_pred):
    return mean_absolute_percentage_error_revise(y_true, y_pred)

# %%
region = 428
length = 16

epochs=150
min_lr=1e-8

myresults={}

train = pd.read_csv(f'csv/{region}.csv', index_col=0)
test = pd.read_csv(f'csv2/{region}.csv', index_col=0)

# %%
# polynomial + scale CSV

# create polynomial features
poly = PolynomialFeatures(2,include_bias=False)
train_poly = pd.DataFrame(poly.fit_transform(train),columns=poly.get_feature_names_out(train.columns))
test_poly = pd.DataFrame(poly.fit_transform(test),columns=poly.get_feature_names_out(test.columns))

# initialise scalers
minmaxscaler = MinMaxScaler(feature_range=(0.1,1))
minmaxscaler.fit(train_poly)
minmaxscalerY = MinMaxScaler(feature_range=(0.1,1))
minmaxscalerY.fit((train[[str(region)]]))

# scale train and test using scalers
scaled_train = pd.DataFrame(minmaxscaler.transform(train_poly),columns=train_poly.columns)
scaled_test = pd.DataFrame(minmaxscaler.transform(test_poly),columns=test_poly.columns)

# %%
# Create time series for CSV
## For testing
data = scaled_test.values
scaled_data = data

X2, y2 = [], []
sequence_length = 16  # X = 16 previous time steps

for i in range(len(scaled_data) - sequence_length):
    X2.append(scaled_data[i:i+sequence_length, :])  # Use all columns
    y2.append(scaled_data[i+sequence_length, 0])  # Assuming prediction is based on the first column

X2, y2 = np.array(X2), np.array(y2)

## For training
data = scaled_train.values
scaled_data = data

X, y = [], []
sequence_length = 16  # X = 16 previous time steps

for i in range(len(scaled_data) - sequence_length):
    X.append(scaled_data[i:i+sequence_length, :])  # Use all columns
    y.append(scaled_data[i+sequence_length, 0])  # Assuming prediction is based on the first column

X, y = np.array(X), np.array(y)

# %%
# Load images

def getalpha():
    theirimg = Image.open("alpha_image/alpha.png")
    alpha = theirimg.convert('RGBA').split()[-1]
    return alpha
alpha = getalpha()

images = []
for f in range(len(glob.glob("images/*.png"))):
    img = PIL.Image.open("images/%d.png"%(int(f)+1))
    r,g,b= img.split()
    bg = PIL.Image.new("RGBA",img.size,(255,255,255) + (255,))
    bg.paste(img,mask=alpha)
    bg = bg.convert('L')
    t,tt = getTT(region)
    bg = bg.crop((tt-32,t-32,tt+32,t+32))
    bg = bg.resize((9,9))
    x = img_to_array(bg)
    images.append(x)
    
images = np.array(images)
images = (images/255.0)


testImages = []
for f in range(len(glob.glob("images2/*.png"))):
    img = PIL.Image.open("images2/%d.png"%(int(f)+1))
    r,g,b= img.split()
    bg = PIL.Image.new("RGBA",img.size,(255,255,255) + (255,))
    bg.paste(img,mask=alpha)
    bg = bg.convert('L')
    t,tt = getTT(region)
    bg = bg.crop((tt-32,t-32,tt+32,t+32))
    bg = bg.resize((9,9))
    x = img_to_array(bg)
    testImages.append(x)

testImages = np.array(testImages)
testImages = (testImages/255.0)

print(testImages.shape,images.shape)
# Out:
# (2976, 9, 9, 1) (2976, 9, 9, 1)

# %%
# time series
# for testing
test_images_ts = []
window_size = 16
for i in range(0, testImages.shape[0] - window_size):
    window = testImages[i:i + window_size]
    test_images_ts.append(window)

# Convert the list to a NumPy array
test_images_ts = np.array(test_images_ts)
print(test_images_ts.shape)

# time series
# for training
train_images_ts = []
window_size = 16
for i in range(0, images.shape[0] - window_size):
    window = images[i:i + window_size]
    train_images_ts.append(window)

# Convert the list to a NumPy array
train_images_ts = np.array(train_images_ts)
print(train_images_ts.shape)
# Out:
# (2960, 16, 9, 9, 1)
# (2960, 16, 9, 9, 1)

# %% [markdown]
# ## CNN

# %%
# split data
train_size = int(len(X) * 0.90)  # 90% training, 10% val
X_train, X_val = X[:train_size], X[train_size:]
train_images_ts, val_images_ts = train_images_ts[:train_size], train_images_ts[train_size:] 
y_train, y_val = y[:train_size], y[train_size:]

# %%
#cnn
# Define the model
model = Sequential()
model.add(Conv3D(filters=32, kernel_size=(3, 3, 3), activation='relu', input_shape=(16, 9, 9, 1), padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same'))
model.add(Conv3D(filters=64, kernel_size=(3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same'))
model.add(Conv3D(filters=128, kernel_size=(3, 3, 3), activation='relu', padding='same'))
model.add(BatchNormalization())
model.add(MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same'))
model.add(Flatten())

#output
model.add(Dense(units=1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss=mean_absolute_percentage_error_revise, metrics=[custom_metric])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_custom_metric', verbose=1,factor=0.5,patience=3, min_lr=min_lr)
checkpointer = ModelCheckpoint(filepath='weights/cnn_weights_dmv_%s_%d.hdf5'%('region',region), monitor='val_custom_metric',verbose=1,mode='min', save_best_only=True,save_weights_only=True)
earlyStoper = EarlyStopping(monitor='val_custom_metric', min_delta=0, patience=20, verbose=1, mode='min')
hist=model.fit(train_images_ts,y_train,batch_size=64,shuffle=False, epochs=epochs,validation_data=(val_images_ts,y_val),callbacks=[earlyStoper,checkpointer,reduce_lr],verbose=1)
# Out:
# Epoch 1/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.5786 - custom_metric: 0.5786
# Epoch 1: val_custom_metric improved from inf to 0.26805, saving model to taxi-demand-prediction/weights-dmv\cnn_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 0.5766 - custom_metric: 0.5764 - val_loss: 0.2702 - val_custom_metric: 0.2681 - lr: 0.0010
# Epoch 2/150
# 42/42 [==============================] - ETA: 0s - loss: 0.5730 - custom_metric: 0.5728
# Epoch 2: val_custom_metric improved from 0.26805 to 0.15513, saving model to taxi-demand-prediction/weights-dmv\cnn_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.1511 - val_custom_metric: 0.1551 - lr: 0.0010
# Epoch 3/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 3: val_custom_metric improved from 0.15513 to 0.14403, saving model to taxi-demand-prediction/weights-dmv\cnn_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.1329 - val_custom_metric: 0.1440 - lr: 0.0010
# Epoch 4/150
# 42/42 [==============================] - ETA: 0s - loss: 0.5730 - custom_metric: 0.5728
# Epoch 4: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.3053 - val_custom_metric: 0.3150 - lr: 0.0010
# Epoch 5/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 5: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.4389 - val_custom_metric: 0.4468 - lr: 0.0010
# Epoch 6/150
# 42/42 [==============================] - ETA: 0s - loss: 0.5730 - custom_metric: 0.5728
# Epoch 6: val_custom_metric did not improve from 0.14403
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5179 - val_custom_metric: 0.5242 - lr: 0.0010
# Epoch 7/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 7: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5556 - val_custom_metric: 0.5610 - lr: 5.0000e-04
# Epoch 8/150
# 38/42 [==========================>...] - ETA: 0s - loss: 0.5746 - custom_metric: 0.5746
# Epoch 8: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5710 - val_custom_metric: 0.5758 - lr: 5.0000e-04
# Epoch 9/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 9: val_custom_metric did not improve from 0.14403
#
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5763 - val_custom_metric: 0.5809 - lr: 5.0000e-04
# Epoch 10/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 10: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5779 - val_custom_metric: 0.5824 - lr: 2.5000e-04
# Epoch 11/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 11: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5783 - val_custom_metric: 0.5828 - lr: 2.5000e-04
# Epoch 12/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 12: val_custom_metric did not improve from 0.14403
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 2.5000e-04
# Epoch 13/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.5739 - custom_metric: 0.5739
# Epoch 13: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 1.2500e-04
# Epoch 14/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 14: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 1.2500e-04
# Epoch 15/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 15: val_custom_metric did not improve from 0.14403
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 1.2500e-04
# Epoch 16/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 16: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 6.2500e-05
# Epoch 17/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 17: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 6.2500e-05
# Epoch 18/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 18: val_custom_metric did not improve from 0.14403
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 6.2500e-05
# Epoch 19/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.5739 - custom_metric: 0.5739
# Epoch 19: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 15ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 3.1250e-05
# Epoch 20/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 20: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 3.1250e-05
# Epoch 21/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 21: val_custom_metric did not improve from 0.14403
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 3.1250e-05
# Epoch 22/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 22: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 1.5625e-05
# Epoch 23/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.5733 - custom_metric: 0.5733
# Epoch 23: val_custom_metric did not improve from 0.14403
# 42/42 [==============================] - 1s 14ms/step - loss: 0.5730 - custom_metric: 0.5728 - val_loss: 0.5784 - val_custom_metric: 0.5829 - lr: 1.5625e-05
# Epoch 23: early stopping

# %%
predictions = model.predict(test_images_ts)
myresults['cnn'] = {'current':{'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}}

model.load_weights(f'weights/cnn_weights_dmv_region_{region}.hdf5')
predictions = model.predict(test_images_ts)
myresults['cnn']['saved'] = {'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}
# Out:
# 93/93 [==============================] - 0s 3ms/step
# 93/93 [==============================] - 0s 2ms/step

# %%
predictions = model.predict(test_images_ts)
print(rmse(y2,predictions))
print(mape(y2,predictions))
print(smape(y2,predictions))
# Out:
# 93/93 [==============================] - 0s 3ms/step
# 0.07630914463131891
# 0.2043339680077725
# 0.25749246006443427

# %%
model.load_weights(f'weights/cnn_weights_dmv_region_{region}.hdf5')
predictions = model.predict(test_images_ts)
print(rmse(y2,predictions))
print(mape(y2,predictions))
print(smape(y2,predictions))
# Out:
# 93/93 [==============================] - 0s 2ms/step
# 0.07630914463131891
# 0.2043339680077725
# 0.25749246006443427

# %% [markdown]
# ## CNN + LSTM

# %%
# CNN branch
image_input = Input(shape=(16, 9, 9, 1), name='image_input')
cnn_branch = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(image_input)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(cnn_branch)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(cnn_branch)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Flatten()(cnn_branch)
cnn_branch = Dense(64, activation='relu')(cnn_branch)
cnn_branch = Dense(16, activation='relu')(cnn_branch)

# LSTM branch
sequence_input = Input(shape=(X_train.shape[1], X_train.shape[2]), name='sequence_input') 
lstm_branch = LSTM(128, return_sequences=True)(sequence_input)

# Reshape the output to add a dummy dimension for Conv1D
lstm_branch_reshaped = Reshape((-1, 128))(lstm_branch)

# TCN layer
tcn_units = 128
dilation_factors = [1, 2, 4, 8, 16, 32, 64]
tcn_layer = lstm_branch_reshaped  # Initialize with the reshaped LSTM output
for dilation in dilation_factors:
    tcn_layer = Conv1D(filters=tcn_units, kernel_size=2, padding='causal', dilation_rate=dilation)(tcn_layer)
tcn_layer = GlobalAveragePooling1D()(tcn_layer)

# Concatenate the outputs of both branches
concatenated = Concatenate()([cnn_branch, tcn_layer])

# Fully connected layers for the concatenated output
final_output = Dense(128, activation='relu')(concatenated)
final_output = Dense(64, activation='relu')(final_output)
final_output = Dense(1, activation='sigmoid')(final_output)

# Create the model
model = Model(inputs=[image_input, sequence_input], outputs=final_output)

# Compile the model
model.compile(optimizer='adam', loss=mean_absolute_percentage_error_revise, metrics=[custom_metric])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_custom_metric', verbose=1,factor=0.5,patience=3, min_lr=min_lr)
checkpointer = ModelCheckpoint(filepath='weights/cnn_lstm_weights_dmv_%s_%d.hdf5'%('region',region), monitor='val_custom_metric',verbose=1,mode='min', save_best_only=True,save_weights_only=True)
earlyStoper = EarlyStopping(monitor='val_custom_metric', min_delta=0, patience=20, verbose=1, mode='min')
hist=model.fit([train_images_ts,X_train],y_train,batch_size=64,shuffle=False, epochs=epochs,validation_data=([val_images_ts,X_val],y_val),callbacks=[earlyStoper,checkpointer,reduce_lr],verbose=1)
# Out:
# Epoch 1/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1209 - custom_metric: 0.1209
# Epoch 1: val_custom_metric improved from inf to 0.46328, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 4s 36ms/step - loss: 0.1195 - custom_metric: 0.1186 - val_loss: 0.4681 - val_custom_metric: 0.4633 - lr: 0.0010
# Epoch 2/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0834 - custom_metric: 0.0834
# Epoch 2: val_custom_metric improved from 0.46328 to 0.45974, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0827 - custom_metric: 0.0823 - val_loss: 0.4649 - val_custom_metric: 0.4597 - lr: 0.0010
# Epoch 3/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0856 - custom_metric: 0.0856
# Epoch 3: val_custom_metric improved from 0.45974 to 0.45436, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0851 - custom_metric: 0.0848 - val_loss: 0.4593 - val_custom_metric: 0.4544 - lr: 0.0010
# Epoch 4/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0898 - custom_metric: 0.0898
# Epoch 4: val_custom_metric improved from 0.45436 to 0.44393, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0871 - custom_metric: 0.0866 - val_loss: 0.4487 - val_custom_metric: 0.4439 - lr: 0.0010
# Epoch 5/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0821 - custom_metric: 0.0821
# Epoch 5: val_custom_metric improved from 0.44393 to 0.42293, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0817 - custom_metric: 0.0814 - val_loss: 0.4276 - val_custom_metric: 0.4229 - lr: 0.0010
# Epoch 6/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1173 - custom_metric: 0.1173
# Epoch 6: val_custom_metric improved from 0.42293 to 0.40015, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.1142 - custom_metric: 0.1137 - val_loss: 0.4045 - val_custom_metric: 0.4001 - lr: 0.0010
# Epoch 7/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0820 - custom_metric: 0.0815
# Epoch 7: val_custom_metric improved from 0.40015 to 0.37227, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0820 - custom_metric: 0.0815 - val_loss: 0.3760 - val_custom_metric: 0.3723 - lr: 0.0010
# Epoch 8/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0920 - custom_metric: 0.0920
# Epoch 8: val_custom_metric improved from 0.37227 to 0.35526, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0912 - custom_metric: 0.0908 - val_loss: 0.3586 - val_custom_metric: 0.3553 - lr: 0.0010
# Epoch 9/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0828 - custom_metric: 0.0828
# Epoch 9: val_custom_metric improved from 0.35526 to 0.30446, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0819 - custom_metric: 0.0813 - val_loss: 0.3069 - val_custom_metric: 0.3045 - lr: 0.0010
# Epoch 10/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.1026 - custom_metric: 0.1026
# Epoch 10: val_custom_metric improved from 0.30446 to 0.26650, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.1019 - custom_metric: 0.1015 - val_loss: 0.2679 - val_custom_metric: 0.2665 - lr: 0.0010
# Epoch 11/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0891 - custom_metric: 0.0891
# Epoch 11: val_custom_metric improved from 0.26650 to 0.21461, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0881 - custom_metric: 0.0876 - val_loss: 0.2140 - val_custom_metric: 0.2146 - lr: 0.0010
# Epoch 12/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0867 - custom_metric: 0.0867
# Epoch 12: val_custom_metric improved from 0.21461 to 0.20133, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0840 - custom_metric: 0.0835 - val_loss: 0.1999 - val_custom_metric: 0.2013 - lr: 0.0010
# Epoch 13/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0844 - custom_metric: 0.0844
# Epoch 13: val_custom_metric improved from 0.20133 to 0.16417, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0836 - custom_metric: 0.0831 - val_loss: 0.1609 - val_custom_metric: 0.1642 - lr: 0.0010
# Epoch 14/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0815 - custom_metric: 0.0815
# Epoch 14: val_custom_metric did not improve from 0.16417
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0796 - custom_metric: 0.0791 - val_loss: 0.1635 - val_custom_metric: 0.1665 - lr: 0.0010
# Epoch 15/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0844 - custom_metric: 0.0844
# Epoch 15: val_custom_metric did not improve from 0.16417
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0837 - custom_metric: 0.0833 - val_loss: 0.1667 - val_custom_metric: 0.1696 - lr: 0.0010
# Epoch 16/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.1029 - custom_metric: 0.1029
# Epoch 16: val_custom_metric improved from 0.16417 to 0.13095, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.1020 - custom_metric: 0.1016 - val_loss: 0.1263 - val_custom_metric: 0.1309 - lr: 0.0010
# Epoch 17/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0933 - custom_metric: 0.0933
# Epoch 17: val_custom_metric improved from 0.13095 to 0.12967, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0923 - custom_metric: 0.0917 - val_loss: 0.1247 - val_custom_metric: 0.1297 - lr: 0.0010
# Epoch 18/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0756 - custom_metric: 0.0756
# Epoch 18: val_custom_metric improved from 0.12967 to 0.09949, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0733 - custom_metric: 0.0728 - val_loss: 0.0918 - val_custom_metric: 0.0995 - lr: 0.0010
# Epoch 19/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0774 - custom_metric: 0.0774
# Epoch 19: val_custom_metric did not improve from 0.09949
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0761 - custom_metric: 0.0758 - val_loss: 0.0961 - val_custom_metric: 0.1036 - lr: 0.0010
# Epoch 20/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0818 - custom_metric: 0.0818
# Epoch 20: val_custom_metric improved from 0.09949 to 0.09948, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0794 - custom_metric: 0.0790 - val_loss: 0.0914 - val_custom_metric: 0.0995 - lr: 0.0010
# Epoch 21/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0831 - custom_metric: 0.0831
# Epoch 21: val_custom_metric did not improve from 0.09948
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0816 - custom_metric: 0.0814 - val_loss: 0.1241 - val_custom_metric: 0.1289 - lr: 0.0010
# Epoch 22/150
# 42/42 [==============================] - ETA: 0s - loss: 0.1005 - custom_metric: 0.0999
# Epoch 22: val_custom_metric did not improve from 0.09948
# 42/42 [==============================] - 1s 27ms/step - loss: 0.1005 - custom_metric: 0.0999 - val_loss: 0.1146 - val_custom_metric: 0.1200 - lr: 5.0000e-04
# Epoch 23/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0759 - custom_metric: 0.0759
# Epoch 23: val_custom_metric improved from 0.09948 to 0.08897, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0752 - custom_metric: 0.0747 - val_loss: 0.0817 - val_custom_metric: 0.0890 - lr: 5.0000e-04
# Epoch 24/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0700 - custom_metric: 0.0700
# Epoch 24: val_custom_metric did not improve from 0.08897
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0694 - custom_metric: 0.0689 - val_loss: 0.0996 - val_custom_metric: 0.1074 - lr: 5.0000e-04
# Epoch 25/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0799 - custom_metric: 0.0799
# Epoch 25: val_custom_metric did not improve from 0.08897
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0790 - custom_metric: 0.0786 - val_loss: 0.0873 - val_custom_metric: 0.0932 - lr: 5.0000e-04
# Epoch 26/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0684 - custom_metric: 0.0680
# Epoch 26: val_custom_metric did not improve from 0.08897
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0684 - custom_metric: 0.0680 - val_loss: 0.0890 - val_custom_metric: 0.0951 - lr: 5.0000e-04
# Epoch 27/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0703 - custom_metric: 0.0703
# Epoch 27: val_custom_metric did not improve from 0.08897
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0682 - custom_metric: 0.0678 - val_loss: 0.0844 - val_custom_metric: 0.0902 - lr: 2.5000e-04
# Epoch 28/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0685 - custom_metric: 0.0685
# Epoch 28: val_custom_metric improved from 0.08897 to 0.08319, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0665 - custom_metric: 0.0661 - val_loss: 0.0777 - val_custom_metric: 0.0832 - lr: 2.5000e-04
# Epoch 29/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0645 - custom_metric: 0.0645
# Epoch 29: val_custom_metric improved from 0.08319 to 0.08175, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0638 - custom_metric: 0.0635 - val_loss: 0.0763 - val_custom_metric: 0.0818 - lr: 2.5000e-04
# Epoch 30/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0643 - custom_metric: 0.0643
# Epoch 30: val_custom_metric did not improve from 0.08175
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0624 - custom_metric: 0.0620 - val_loss: 0.0776 - val_custom_metric: 0.0831 - lr: 2.5000e-04
# Epoch 31/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0621 - custom_metric: 0.0621
# Epoch 31: val_custom_metric did not improve from 0.08175
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0615 - custom_metric: 0.0611 - val_loss: 0.0803 - val_custom_metric: 0.0861 - lr: 2.5000e-04
# Epoch 32/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0648 - custom_metric: 0.0648
# Epoch 32: val_custom_metric did not improve from 0.08175
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0631 - custom_metric: 0.0628 - val_loss: 0.0857 - val_custom_metric: 0.0902 - lr: 2.5000e-04
# Epoch 33/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0632 - custom_metric: 0.0632
# Epoch 33: val_custom_metric did not improve from 0.08175
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0626 - custom_metric: 0.0622 - val_loss: 0.0817 - val_custom_metric: 0.0860 - lr: 1.2500e-04
# Epoch 34/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0629 - custom_metric: 0.0629
# Epoch 34: val_custom_metric did not improve from 0.08175
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0610 - custom_metric: 0.0606 - val_loss: 0.0795 - val_custom_metric: 0.0839 - lr: 1.2500e-04
# Epoch 35/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0605 - custom_metric: 0.0605
# Epoch 35: val_custom_metric did not improve from 0.08175
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0599 - custom_metric: 0.0595 - val_loss: 0.0854 - val_custom_metric: 0.0896 - lr: 1.2500e-04
# Epoch 36/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0630 - custom_metric: 0.0630
# Epoch 36: val_custom_metric did not improve from 0.08175
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0611 - custom_metric: 0.0607 - val_loss: 0.0774 - val_custom_metric: 0.0818 - lr: 6.2500e-05
# Epoch 37/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0610 - custom_metric: 0.0610
# Epoch 37: val_custom_metric improved from 0.08175 to 0.08093, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0604 - custom_metric: 0.0600 - val_loss: 0.0764 - val_custom_metric: 0.0809 - lr: 6.2500e-05
# Epoch 38/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0604 - custom_metric: 0.0604
# Epoch 38: val_custom_metric improved from 0.08093 to 0.07995, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0598 - custom_metric: 0.0594 - val_loss: 0.0754 - val_custom_metric: 0.0799 - lr: 6.2500e-05
# Epoch 39/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0603 - custom_metric: 0.0603
# Epoch 39: val_custom_metric did not improve from 0.07995
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0597 - custom_metric: 0.0593 - val_loss: 0.0764 - val_custom_metric: 0.0809 - lr: 6.2500e-05
# Epoch 40/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0601 - custom_metric: 0.0601
# Epoch 40: val_custom_metric improved from 0.07995 to 0.07928, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0595 - custom_metric: 0.0591 - val_loss: 0.0747 - val_custom_metric: 0.0793 - lr: 6.2500e-05
# Epoch 41/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0596 - custom_metric: 0.0596
# Epoch 41: val_custom_metric did not improve from 0.07928
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0590 - custom_metric: 0.0587 - val_loss: 0.0769 - val_custom_metric: 0.0812 - lr: 6.2500e-05
# Epoch 42/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0591 - custom_metric: 0.0591
# Epoch 42: val_custom_metric did not improve from 0.07928
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0585 - custom_metric: 0.0582 - val_loss: 0.0779 - val_custom_metric: 0.0822 - lr: 6.2500e-05
# Epoch 43/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0586 - custom_metric: 0.0586
# Epoch 43: val_custom_metric did not improve from 0.07928
#
# Epoch 43: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0580 - custom_metric: 0.0577 - val_loss: 0.0765 - val_custom_metric: 0.0808 - lr: 6.2500e-05
# Epoch 44/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0589 - custom_metric: 0.0589
# Epoch 44: val_custom_metric improved from 0.07928 to 0.07566, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0583 - custom_metric: 0.0580 - val_loss: 0.0706 - val_custom_metric: 0.0757 - lr: 3.1250e-05
# Epoch 45/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0576 - custom_metric: 0.0576
# Epoch 45: val_custom_metric did not improve from 0.07566
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0571 - custom_metric: 0.0567 - val_loss: 0.0711 - val_custom_metric: 0.0760 - lr: 3.1250e-05
# Epoch 46/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0587 - custom_metric: 0.0587
# Epoch 46: val_custom_metric did not improve from 0.07566
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0569 - custom_metric: 0.0566 - val_loss: 0.0719 - val_custom_metric: 0.0766 - lr: 3.1250e-05
# Epoch 47/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0573 - custom_metric: 0.0573
# Epoch 47: val_custom_metric did not improve from 0.07566
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0567 - custom_metric: 0.0564 - val_loss: 0.0724 - val_custom_metric: 0.0770 - lr: 3.1250e-05
# Epoch 48/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0569 - custom_metric: 0.0569
# Epoch 48: val_custom_metric improved from 0.07566 to 0.07550, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0563 - custom_metric: 0.0560 - val_loss: 0.0706 - val_custom_metric: 0.0755 - lr: 1.5625e-05
# Epoch 49/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0565 - custom_metric: 0.0565
# Epoch 49: val_custom_metric did not improve from 0.07550
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0559 - custom_metric: 0.0556 - val_loss: 0.0708 - val_custom_metric: 0.0756 - lr: 1.5625e-05
# Epoch 50/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0565 - custom_metric: 0.0565
# Epoch 50: val_custom_metric improved from 0.07550 to 0.07550, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0559 - custom_metric: 0.0556 - val_loss: 0.0707 - val_custom_metric: 0.0755 - lr: 1.5625e-05
# Epoch 51/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0564 - custom_metric: 0.0564
# Epoch 51: val_custom_metric did not improve from 0.07550
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0558 - custom_metric: 0.0555 - val_loss: 0.0709 - val_custom_metric: 0.0756 - lr: 1.5625e-05
# Epoch 52/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0559 - custom_metric: 0.0559
# Epoch 52: val_custom_metric improved from 0.07550 to 0.07526, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0554 - custom_metric: 0.0550 - val_loss: 0.0705 - val_custom_metric: 0.0753 - lr: 7.8125e-06
# Epoch 53/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0569 - custom_metric: 0.0569
# Epoch 53: val_custom_metric did not improve from 0.07526
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0551 - custom_metric: 0.0548 - val_loss: 0.0707 - val_custom_metric: 0.0753 - lr: 7.8125e-06
# Epoch 54/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0568 - custom_metric: 0.0568
# Epoch 54: val_custom_metric did not improve from 0.07526
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0551 - custom_metric: 0.0548 - val_loss: 0.0708 - val_custom_metric: 0.0754 - lr: 7.8125e-06
# Epoch 55/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0568 - custom_metric: 0.0568
# Epoch 55: val_custom_metric did not improve from 0.07526
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0550 - custom_metric: 0.0547 - val_loss: 0.0707 - val_custom_metric: 0.0753 - lr: 7.8125e-06
# Epoch 56/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0566 - custom_metric: 0.0566
# Epoch 56: val_custom_metric improved from 0.07526 to 0.07514, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0549 - custom_metric: 0.0546 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 3.9063e-06
# Epoch 57/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0566 - custom_metric: 0.0566
# Epoch 57: val_custom_metric improved from 0.07514 to 0.07513, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0548 - custom_metric: 0.0545 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 3.9063e-06
# Epoch 58/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0553 - custom_metric: 0.0553
# Epoch 58: val_custom_metric improved from 0.07513 to 0.07510, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0548 - custom_metric: 0.0545 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 3.9063e-06
# Epoch 59/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0565 - custom_metric: 0.0565
# Epoch 59: val_custom_metric did not improve from 0.07510
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0548 - custom_metric: 0.0544 - val_loss: 0.0706 - val_custom_metric: 0.0751 - lr: 3.9063e-06
# Epoch 60/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0552 - custom_metric: 0.0552
# Epoch 60: val_custom_metric improved from 0.07510 to 0.07509, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0547 - custom_metric: 0.0544 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 1.9531e-06
# Epoch 61/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0552 - custom_metric: 0.0552
# Epoch 61: val_custom_metric improved from 0.07509 to 0.07508, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0547 - custom_metric: 0.0544 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 1.9531e-06
# Epoch 62/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0552 - custom_metric: 0.0552
# Epoch 62: val_custom_metric did not improve from 0.07508
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0547 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 1.9531e-06
# Epoch 63/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0552 - custom_metric: 0.0552
# Epoch 63: val_custom_metric improved from 0.07508 to 0.07507, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 9.7656e-07
# Epoch 64/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0552 - custom_metric: 0.0552
# Epoch 64: val_custom_metric improved from 0.07507 to 0.07505, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0751 - lr: 9.7656e-07
# Epoch 65/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0552 - custom_metric: 0.0552
# Epoch 65: val_custom_metric improved from 0.07505 to 0.07504, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 65: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 9.7656e-07
# Epoch 66/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 66: val_custom_metric did not improve from 0.07504
# 42/42 [==============================] - 1s 27ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 4.8828e-07
# Epoch 67/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 67: val_custom_metric improved from 0.07504 to 0.07504, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 4.8828e-07
# Epoch 68/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 68: val_custom_metric improved from 0.07504 to 0.07504, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 4.8828e-07
# Epoch 69/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 69: val_custom_metric improved from 0.07504 to 0.07504, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0543 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 4.8828e-07
# Epoch 70/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 70: val_custom_metric improved from 0.07504 to 0.07503, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 4.8828e-07
# Epoch 71/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 71: val_custom_metric improved from 0.07503 to 0.07503, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 71: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 4.8828e-07
# Epoch 72/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 72: val_custom_metric improved from 0.07503 to 0.07503, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 2.4414e-07
# Epoch 73/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 73: val_custom_metric improved from 0.07503 to 0.07503, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 2.4414e-07
# Epoch 74/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 74: val_custom_metric improved from 0.07503 to 0.07503, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 74: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 2.4414e-07
# Epoch 75/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 75: val_custom_metric improved from 0.07503 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.2207e-07
# Epoch 76/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 76: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0546 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.2207e-07
# Epoch 77/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 77: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 77: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.2207e-07
# Epoch 78/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 78: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 6.1035e-08
# Epoch 79/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0545 - custom_metric: 0.0542
# Epoch 79: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 6.1035e-08
# Epoch 80/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 80: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 80: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 6.1035e-08
# Epoch 81/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 81: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 3.0518e-08
# Epoch 82/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 82: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 3.0518e-08
# Epoch 83/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 83: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 83: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 3.0518e-08
# Epoch 84/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 84: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.5259e-08
# Epoch 85/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 85: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.5259e-08
# Epoch 86/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 86: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
#
# Epoch 86: ReduceLROnPlateau reducing learning rate to 1e-08.
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.5259e-08
# Epoch 87/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 87: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 88/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 88: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 89/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 89: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 90/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 90: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 91/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 91: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 92/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 92: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 93/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 93: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 94/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 94: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 95/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 95: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 96/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 96: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 97/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 97: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 98/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 98: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 99/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 99: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 100/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 100: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 101/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 101: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 102/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 102: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 103/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 103: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 104/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 104: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 105/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 105: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 106/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 106: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 107/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 107: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 108/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 108: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 109/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 109: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 110/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 110: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 111/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 111: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 112/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 112: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 113/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 113: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 114/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 114: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 115/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 115: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 116/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 116: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 117/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 117: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 118/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 118: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 119/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 119: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 120/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 120: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 121/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 121: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 122/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 122: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 123/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 123: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 124/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 124: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 125/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 125: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 126/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 126: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 127/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 127: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 128/150
# 42/42 [==============================] - ETA: 0s - loss: 0.0545 - custom_metric: 0.0542
# Epoch 128: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 30ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 129/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 129: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 30ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 130/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 130: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 30ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 131/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 131: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 132/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 132: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 133/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 133: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 134/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 134: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 135/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 135: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 136/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 136: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 137/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 137: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 138/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 138: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 139/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 139: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 140/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 140: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 141/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 141: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 142/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 142: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 143/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 143: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 144/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 144: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 145/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 145: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 146/150
# 40/42 [===========================>..] - ETA: 0s - loss: 0.0563 - custom_metric: 0.0563
# Epoch 146: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 147/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 147: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 148/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 148: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 29ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 149/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 149: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08
# Epoch 150/150
# 41/42 [============================>.] - ETA: 0s - loss: 0.0551 - custom_metric: 0.0551
# Epoch 150: val_custom_metric improved from 0.07502 to 0.07502, saving model to taxi-demand-prediction/weights-dmv\cnn_lstm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 0.0545 - custom_metric: 0.0542 - val_loss: 0.0705 - val_custom_metric: 0.0750 - lr: 1.0000e-08

# %%
predictions = model.predict([test_images_ts,X2])
myresults['cnn_lstm'] = {'current':{'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}}

model.load_weights(f'weights/cnn_lstm_weights_dmv_region_{region}.hdf5')
predictions = model.predict([test_images_ts,X2])
myresults['cnn_lstm']['saved'] = {'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}
# Out:
# 93/93 [==============================] - 1s 5ms/step
# 93/93 [==============================] - 0s 5ms/step

# %%
for m, v in myresults.items():
    print(m)
    print(v['current'])
    print(v['saved'])
# Out:
# cnn
# {'rmse': 0.14062757013936295, 'mape': 0.9999999999033546, 'smape': 1.9999999996134143}
# {'rmse': 0.07630914463131891, 'mape': 0.2043339680077725, 'smape': 0.25749246006443427}
# cnn_lstm
# {'rmse': 0.07726500147678773, 'mape': 0.2520683590886466, 'smape': 0.23231039629746475}
# {'rmse': 0.07726500147678773, 'mape': 0.2520683590886466, 'smape': 0.23231039629746475}

# %% [markdown]
# ## CNN + LSTM + Micro

# %%
# split data
#train_size = int(len(X) * 0.90)  # 90% training, 10% val
#X_train, X_val = X[:train_size], X[train_size:]
#y_train, y_val = y[:train_size], y[train_size:]
#train_images_ts, val_images_ts = train_images_ts[:train_size], train_images_ts[train_size:]

# %%
sequence_length = 16
my_m_input_train = pd.read_csv(f'micro/{region}.csv', index_col=0)
my_m_input_test = pd.read_csv(f'micro2/{region}.csv', index_col=0)
mydata_train = my_m_input_train.values
mydata_test = my_m_input_test.values

my_m_data_train = []
my_m_data_test = []

for i in range(len(mydata_train) - sequence_length):
    my_m_data_train.append(mydata_train[i:i+sequence_length])
    
for i in range(len(mydata_test) - sequence_length):
    my_m_data_test.append(mydata_test[i:i+sequence_length])

my_m_data_train = np.array(my_m_data_train)
my_m_data_test = np.array(my_m_data_test)

train_size = int(len(X) * 0.90)  # 90% training, 10% val
m_train_data, m_val_data = my_m_data_train[:train_size], my_m_data_train[train_size:]

# %%
mscaler = MinMaxScaler(feature_range=(0.1,1))
mscaler.fit(m_train_data)
m_train_data = pd.DataFrame(mscaler.transform(m_train_data))
m_val_data = pd.DataFrame(mscaler.transform(m_val_data))
my_m_data_test = pd.DataFrame(mscaler.transform(my_m_data_test))

# %%
# CNN branch
image_input = Input(shape=(16, 9, 9, 1), name='image_input')
cnn_branch = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(image_input)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(cnn_branch)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(cnn_branch)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Flatten()(cnn_branch)
cnn_branch = Dense(64, activation='relu')(cnn_branch)
cnn_branch = Dense(16, activation='relu')(cnn_branch)

# LSTM branch
sequence_input = Input(shape=(X_train.shape[1], X_train.shape[2]), name='sequence_input') 
lstm_branch = LSTM(128, return_sequences=True)(sequence_input)


lstm_branch_reshaped = Reshape((-1, 128))(lstm_branch)

# TCN layer
tcn_units = 128
dilation_factors = [1, 2, 4, 8, 16, 32, 64]
tcn_layer = lstm_branch_reshaped  # Initialize with the reshaped LSTM output
for dilation in dilation_factors:
    tcn_layer = Conv1D(filters=tcn_units, kernel_size=2, padding='causal', dilation_rate=dilation)(tcn_layer)
tcn_layer = GlobalAveragePooling1D()(tcn_layer)

# M branch
micro_input = Input(shape=(m_train.shape[1], m_train.shape[2]), name='micro_input') 
m_branch = LSTM(128, return_sequences=True)(m_input)
m_branch = LSTM(128, return_sequences=True)(m_branch)

# Concatenate the outputs of both branches
concatenated = Concatenate()([cnn_branch, tcn_layer, m_branch])

# Fully connected layers for the concatenated output
final_output = Dense(128, activation='relu')(concatenated)
final_output = Dense(64, activation='relu')(final_output)
final_output = Dense(1, activation='sigmoid')(final_output)

# Create the model
model = Model(inputs=[image_input, sequence_input, micro_input], outputs=final_output)

# Compile the model
model.compile(optimizer='adam', loss=mean_absolute_percentage_error_revise, metrics=[custom_metric])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 17
#      14 cnn_branch = Dense(16, activation='relu')(cnn_branch)
#      16 # LSTM branch
# ---> 17 sequence_input = Input(shape=(X_train.shape[1], X_train.shape[2]), name='sequence_input')
#      18 lstm_branch = LSTM(128, return_sequences=True)(sequence_input)
#      21 lstm_branch_reshaped = Reshape((-1, 128))(lstm_branch)
#
# NameError: name 'X_train' is not defined

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_custom_metric', verbose=1,factor=0.5,patience=3, min_lr=min_lr)
checkpointer = ModelCheckpoint(filepath='weights/mm_weights_dmv_%s_%d.hdf5'%('region',region), monitor='val_custom_metric',verbose=1,mode='min', save_best_only=True,save_weights_only=True)
earlyStoper = EarlyStopping(monitor='val_custom_metric', min_delta=0, patience=20, verbose=1, mode='min')
hist=model.fit([train_images_ts,X_train, m_train_data],y_train,batch_size=64,shuffle=False, epochs=epochs,validation_data=([val_images_ts,X_val,m_val_data],y_val),callbacks=[earlyStoper,checkpointer,reduce_lr],verbose=1)
# Out:
# Epoch 1/150
# 40/42 [===========================>..] - ETA: 0s - loss: 17.1413 - custom_metric: 17.1413
# Epoch 1: val_custom_metric improved from inf to 42.36444, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 4s 37ms/step - loss: 17.3620 - custom_metric: 17.4214 - val_loss: 43.6083 - val_custom_metric: 42.3644 - lr: 0.0010
# Epoch 2/150
# 40/42 [===========================>..] - ETA: 0s - loss: 13.7611 - custom_metric: 13.7611
# Epoch 2: val_custom_metric improved from 42.36444 to 37.61486, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 13.6308 - custom_metric: 13.5711 - val_loss: 38.7856 - val_custom_metric: 37.6149 - lr: 0.0010
# Epoch 3/150
# 41/42 [============================>.] - ETA: 0s - loss: 12.3437 - custom_metric: 12.3437
# Epoch 3: val_custom_metric improved from 37.61486 to 36.15530, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 12.5028 - custom_metric: 12.5960 - val_loss: 37.3339 - val_custom_metric: 36.1553 - lr: 0.0010
# Epoch 4/150
# 41/42 [============================>.] - ETA: 0s - loss: 12.0274 - custom_metric: 12.0274
# Epoch 4: val_custom_metric improved from 36.15530 to 35.22800, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 11.9699 - custom_metric: 11.9362 - val_loss: 36.2949 - val_custom_metric: 35.2280 - lr: 0.0010
# Epoch 5/150
# 42/42 [==============================] - ETA: 0s - loss: 13.7412 - custom_metric: 13.7409
# Epoch 5: val_custom_metric improved from 35.22800 to 30.78052, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 26ms/step - loss: 13.7412 - custom_metric: 13.7409 - val_loss: 31.7767 - val_custom_metric: 30.7805 - lr: 0.0010
# Epoch 6/150
# 40/42 [===========================>..] - ETA: 0s - loss: 11.9487 - custom_metric: 11.9487
# Epoch 6: val_custom_metric improved from 30.78052 to 28.29731, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 11.9575 - custom_metric: 11.9435 - val_loss: 29.1593 - val_custom_metric: 28.2973 - lr: 0.0010
# Epoch 7/150
# 40/42 [===========================>..] - ETA: 0s - loss: 11.4775 - custom_metric: 11.4775
# Epoch 7: val_custom_metric improved from 28.29731 to 26.76680, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 11.4901 - custom_metric: 11.4844 - val_loss: 27.5279 - val_custom_metric: 26.7668 - lr: 0.0010
# Epoch 8/150
# 41/42 [============================>.] - ETA: 0s - loss: 9.4954 - custom_metric: 9.4954
# Epoch 8: val_custom_metric improved from 26.76680 to 26.74883, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 9.4558 - custom_metric: 9.4326 - val_loss: 27.5220 - val_custom_metric: 26.7488 - lr: 0.0010
# Epoch 9/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.6170 - custom_metric: 8.6170
# Epoch 9: val_custom_metric improved from 26.74883 to 26.18304, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 8.6807 - custom_metric: 8.6696 - val_loss: 26.9748 - val_custom_metric: 26.1830 - lr: 0.0010
# Epoch 10/150
# 42/42 [==============================] - ETA: 0s - loss: 8.7468 - custom_metric: 8.7313
# Epoch 10: val_custom_metric improved from 26.18304 to 24.35228, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 8.7468 - custom_metric: 8.7313 - val_loss: 25.0508 - val_custom_metric: 24.3523 - lr: 0.0010
# Epoch 11/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.9621 - custom_metric: 8.9621
# Epoch 11: val_custom_metric improved from 24.35228 to 20.92483, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 8.9995 - custom_metric: 8.9882 - val_loss: 21.4964 - val_custom_metric: 20.9248 - lr: 0.0010
# Epoch 12/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.7026 - custom_metric: 8.7026
# Epoch 12: val_custom_metric improved from 20.92483 to 19.84368, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 8.7471 - custom_metric: 8.7380 - val_loss: 20.2966 - val_custom_metric: 19.8437 - lr: 0.0010
# Epoch 13/150
# 41/42 [============================>.] - ETA: 0s - loss: 9.8311 - custom_metric: 9.8311
# Epoch 13: val_custom_metric improved from 19.84368 to 19.48933, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 9.7921 - custom_metric: 9.7692 - val_loss: 19.7433 - val_custom_metric: 19.4893 - lr: 0.0010
# Epoch 14/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.9782 - custom_metric: 8.9782
# Epoch 14: val_custom_metric improved from 19.48933 to 13.28565, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 8.9946 - custom_metric: 8.9794 - val_loss: 13.3611 - val_custom_metric: 13.2856 - lr: 0.0010
# Epoch 15/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.4939 - custom_metric: 8.4939
# Epoch 15: val_custom_metric improved from 13.28565 to 9.87233, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 28ms/step - loss: 8.5781 - custom_metric: 8.5651 - val_loss: 9.7295 - val_custom_metric: 9.8723 - lr: 0.0010
# Epoch 16/150
# 41/42 [============================>.] - ETA: 0s - loss: 10.7583 - custom_metric: 10.7583
# Epoch 16: val_custom_metric did not improve from 9.87233
# 42/42 [==============================] - 1s 27ms/step - loss: 10.7831 - custom_metric: 10.7976 - val_loss: 15.2458 - val_custom_metric: 15.1240 - lr: 0.0010
# Epoch 17/150
# 41/42 [============================>.] - ETA: 0s - loss: 11.2618 - custom_metric: 11.2618
# Epoch 17: val_custom_metric did not improve from 9.87233
# 42/42 [==============================] - 1s 27ms/step - loss: 11.2126 - custom_metric: 11.1837 - val_loss: 14.5384 - val_custom_metric: 14.4644 - lr: 0.0010
# Epoch 18/150
# 40/42 [===========================>..] - ETA: 0s - loss: 7.9100 - custom_metric: 7.9100
# Epoch 18: val_custom_metric did not improve from 9.87233
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 1s 27ms/step - loss: 7.9655 - custom_metric: 7.9670 - val_loss: 10.9845 - val_custom_metric: 11.0765 - lr: 0.0010
# Epoch 19/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.1409 - custom_metric: 8.1409
# Epoch 19: val_custom_metric improved from 9.87233 to 8.02197, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 8.1716 - custom_metric: 8.1598 - val_loss: 7.7122 - val_custom_metric: 8.0220 - lr: 5.0000e-04
# Epoch 20/150
# 40/42 [===========================>..] - ETA: 0s - loss: 7.3734 - custom_metric: 7.3734
# Epoch 20: val_custom_metric did not improve from 8.02197
# 42/42 [==============================] - 1s 26ms/step - loss: 7.4388 - custom_metric: 7.4382 - val_loss: 8.1899 - val_custom_metric: 8.3963 - lr: 5.0000e-04
# Epoch 21/150
# 42/42 [==============================] - ETA: 0s - loss: 7.6974 - custom_metric: 7.6950
# Epoch 21: val_custom_metric improved from 8.02197 to 7.98243, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 7.6974 - custom_metric: 7.6950 - val_loss: 7.7251 - val_custom_metric: 7.9824 - lr: 5.0000e-04
# Epoch 22/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.5522 - custom_metric: 7.5522
# Epoch 22: val_custom_metric improved from 7.98243 to 7.83733, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 7.5509 - custom_metric: 7.5501 - val_loss: 7.6032 - val_custom_metric: 7.8373 - lr: 5.0000e-04
# Epoch 23/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.3903 - custom_metric: 7.3903
# Epoch 23: val_custom_metric did not improve from 7.83733
# 42/42 [==============================] - 1s 26ms/step - loss: 7.3857 - custom_metric: 7.3830 - val_loss: 7.9825 - val_custom_metric: 8.1758 - lr: 5.0000e-04
# Epoch 24/150
# 42/42 [==============================] - ETA: 0s - loss: 7.5230 - custom_metric: 7.5186
# Epoch 24: val_custom_metric did not improve from 7.83733
# 42/42 [==============================] - 1s 26ms/step - loss: 7.5230 - custom_metric: 7.5186 - val_loss: 8.7371 - val_custom_metric: 8.9185 - lr: 5.0000e-04
# Epoch 25/150
# 42/42 [==============================] - ETA: 0s - loss: 7.7210 - custom_metric: 7.7095
# Epoch 25: val_custom_metric did not improve from 7.83733
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 1s 27ms/step - loss: 7.7210 - custom_metric: 7.7095 - val_loss: 8.0055 - val_custom_metric: 8.2013 - lr: 5.0000e-04
# Epoch 26/150
# 42/42 [==============================] - ETA: 0s - loss: 7.4340 - custom_metric: 7.4232
# Epoch 26: val_custom_metric did not improve from 7.83733
# 42/42 [==============================] - 1s 26ms/step - loss: 7.4340 - custom_metric: 7.4232 - val_loss: 8.3868 - val_custom_metric: 8.6489 - lr: 2.5000e-04
# Epoch 27/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.2911 - custom_metric: 7.2911
# Epoch 27: val_custom_metric did not improve from 7.83733
# 42/42 [==============================] - 1s 26ms/step - loss: 7.2729 - custom_metric: 7.2622 - val_loss: 8.0023 - val_custom_metric: 8.2694 - lr: 2.5000e-04
# Epoch 28/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.2460 - custom_metric: 7.2460
# Epoch 28: val_custom_metric improved from 7.83733 to 7.80036, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 7.2294 - custom_metric: 7.2197 - val_loss: 7.5377 - val_custom_metric: 7.8004 - lr: 2.5000e-04
# Epoch 29/150
# 42/42 [==============================] - ETA: 0s - loss: 7.1891 - custom_metric: 7.1776
# Epoch 29: val_custom_metric did not improve from 7.80036
# 42/42 [==============================] - 1s 27ms/step - loss: 7.1891 - custom_metric: 7.1776 - val_loss: 7.7930 - val_custom_metric: 8.0846 - lr: 2.5000e-04
# Epoch 30/150
# 42/42 [==============================] - ETA: 0s - loss: 6.9870 - custom_metric: 6.9770
# Epoch 30: val_custom_metric did not improve from 7.80036
# 42/42 [==============================] - 1s 27ms/step - loss: 6.9870 - custom_metric: 6.9770 - val_loss: 7.6154 - val_custom_metric: 7.8947 - lr: 2.5000e-04
# Epoch 31/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.9203 - custom_metric: 6.9203
# Epoch 31: val_custom_metric improved from 7.80036 to 7.43366, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 6.9597 - custom_metric: 6.9497 - val_loss: 7.2023 - val_custom_metric: 7.4337 - lr: 2.5000e-04
# Epoch 32/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.9674 - custom_metric: 6.9674
# Epoch 32: val_custom_metric improved from 7.43366 to 7.39322, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 7.0019 - custom_metric: 6.9903 - val_loss: 7.1642 - val_custom_metric: 7.3932 - lr: 2.5000e-04
# Epoch 33/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.0200 - custom_metric: 7.0200
# Epoch 33: val_custom_metric did not improve from 7.39322
# 42/42 [==============================] - 1s 27ms/step - loss: 6.9978 - custom_metric: 6.9849 - val_loss: 7.3704 - val_custom_metric: 7.6246 - lr: 2.5000e-04
# Epoch 34/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.0855 - custom_metric: 7.0855
# Epoch 34: val_custom_metric did not improve from 7.39322
# 42/42 [==============================] - 1s 26ms/step - loss: 7.0610 - custom_metric: 7.0467 - val_loss: 7.9682 - val_custom_metric: 8.2802 - lr: 2.5000e-04
# Epoch 35/150
# 42/42 [==============================] - ETA: 0s - loss: 7.0915 - custom_metric: 7.0760
# Epoch 35: val_custom_metric did not improve from 7.39322
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 1s 26ms/step - loss: 7.0915 - custom_metric: 7.0760 - val_loss: 9.2452 - val_custom_metric: 9.5890 - lr: 2.5000e-04
# Epoch 36/150
# 42/42 [==============================] - ETA: 0s - loss: 6.6589 - custom_metric: 6.6536
# Epoch 36: val_custom_metric did not improve from 7.39322
# 42/42 [==============================] - 1s 26ms/step - loss: 6.6589 - custom_metric: 6.6536 - val_loss: 7.1899 - val_custom_metric: 7.4260 - lr: 1.2500e-04
# Epoch 37/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.4858 - custom_metric: 6.4858
# Epoch 37: val_custom_metric did not improve from 7.39322
# 42/42 [==============================] - 1s 26ms/step - loss: 6.4666 - custom_metric: 6.4553 - val_loss: 7.6779 - val_custom_metric: 7.9533 - lr: 1.2500e-04
# Epoch 38/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.3861 - custom_metric: 6.3861
# Epoch 38: val_custom_metric improved from 7.39322 to 7.32469, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 26ms/step - loss: 6.4184 - custom_metric: 6.4070 - val_loss: 7.1076 - val_custom_metric: 7.3247 - lr: 1.2500e-04
# Epoch 39/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.3883 - custom_metric: 6.3883
# Epoch 39: val_custom_metric improved from 7.32469 to 7.29695, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 6.3680 - custom_metric: 6.3562 - val_loss: 7.0891 - val_custom_metric: 7.2969 - lr: 1.2500e-04
# Epoch 40/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.3606 - custom_metric: 6.3606
# Epoch 40: val_custom_metric did not improve from 7.29695
# 42/42 [==============================] - 1s 27ms/step - loss: 6.3943 - custom_metric: 6.3842 - val_loss: 7.1563 - val_custom_metric: 7.3738 - lr: 1.2500e-04
# Epoch 41/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.3301 - custom_metric: 6.3301
# Epoch 41: val_custom_metric improved from 7.29695 to 7.27415, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 26ms/step - loss: 6.3098 - custom_metric: 6.2979 - val_loss: 7.0698 - val_custom_metric: 7.2741 - lr: 1.2500e-04
# Epoch 42/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.2287 - custom_metric: 6.2287
# Epoch 42: val_custom_metric did not improve from 7.27415
# 42/42 [==============================] - 1s 26ms/step - loss: 6.2550 - custom_metric: 6.2403 - val_loss: 7.1999 - val_custom_metric: 7.4104 - lr: 1.2500e-04
# Epoch 43/150
# 42/42 [==============================] - ETA: 0s - loss: 6.2922 - custom_metric: 6.2778
# Epoch 43: val_custom_metric did not improve from 7.27415
# 42/42 [==============================] - 1s 27ms/step - loss: 6.2922 - custom_metric: 6.2778 - val_loss: 7.9094 - val_custom_metric: 8.1769 - lr: 1.2500e-04
# Epoch 44/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.3854 - custom_metric: 6.3854
# Epoch 44: val_custom_metric did not improve from 7.27415
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 1s 27ms/step - loss: 6.3588 - custom_metric: 6.3432 - val_loss: 7.5490 - val_custom_metric: 7.7856 - lr: 1.2500e-04
# Epoch 45/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.2386 - custom_metric: 6.2386
# Epoch 45: val_custom_metric did not improve from 7.27415
# 42/42 [==============================] - 1s 26ms/step - loss: 6.2153 - custom_metric: 6.2016 - val_loss: 7.3616 - val_custom_metric: 7.5907 - lr: 6.2500e-05
# Epoch 46/150
# 42/42 [==============================] - ETA: 0s - loss: 6.2844 - custom_metric: 6.2686
# Epoch 46: val_custom_metric did not improve from 7.27415
# 42/42 [==============================] - 1s 27ms/step - loss: 6.2844 - custom_metric: 6.2686 - val_loss: 7.6922 - val_custom_metric: 7.9509 - lr: 6.2500e-05
# Epoch 47/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.1162 - custom_metric: 6.1162
# Epoch 47: val_custom_metric did not improve from 7.27415
#
# Epoch 47: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 42/42 [==============================] - 1s 26ms/step - loss: 6.1301 - custom_metric: 6.1137 - val_loss: 7.5723 - val_custom_metric: 7.8215 - lr: 6.2500e-05
# Epoch 48/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.1368 - custom_metric: 6.1368
# Epoch 48: val_custom_metric did not improve from 7.27415
# 42/42 [==============================] - 1s 26ms/step - loss: 6.1086 - custom_metric: 6.0920 - val_loss: 7.1203 - val_custom_metric: 7.3207 - lr: 3.1250e-05
# Epoch 49/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.0799 - custom_metric: 6.0799
# Epoch 49: val_custom_metric did not improve from 7.27415
# 42/42 [==============================] - 1s 26ms/step - loss: 6.0935 - custom_metric: 6.0769 - val_loss: 7.1185 - val_custom_metric: 7.3148 - lr: 3.1250e-05
# Epoch 50/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.0502 - custom_metric: 6.0502
# Epoch 50: val_custom_metric did not improve from 7.27415
#
# Epoch 50: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 42/42 [==============================] - 1s 26ms/step - loss: 6.0635 - custom_metric: 6.0459 - val_loss: 7.0942 - val_custom_metric: 7.2855 - lr: 3.1250e-05
# Epoch 51/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.0251 - custom_metric: 6.0251
# Epoch 51: val_custom_metric improved from 7.27415 to 7.16820, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 6.0383 - custom_metric: 6.0224 - val_loss: 6.9840 - val_custom_metric: 7.1682 - lr: 1.5625e-05
# Epoch 52/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.0193 - custom_metric: 6.0193
# Epoch 52: val_custom_metric improved from 7.16820 to 7.14555, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 6.0295 - custom_metric: 6.0124 - val_loss: 6.9626 - val_custom_metric: 7.1456 - lr: 1.5625e-05
# Epoch 53/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.0504 - custom_metric: 6.0504
# Epoch 53: val_custom_metric did not improve from 7.14555
# 42/42 [==============================] - 1s 26ms/step - loss: 6.0204 - custom_metric: 6.0029 - val_loss: 6.9749 - val_custom_metric: 7.1587 - lr: 1.5625e-05
# Epoch 54/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.0051 - custom_metric: 6.0051
# Epoch 54: val_custom_metric improved from 7.14555 to 7.13722, saving model to taxi-demand-prediction/weights-dmv\mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 27ms/step - loss: 6.0132 - custom_metric: 5.9952 - val_loss: 6.9557 - val_custom_metric: 7.1372 - lr: 1.5625e-05
# Epoch 55/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.9971 - custom_metric: 5.9971
# Epoch 55: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 6.0047 - custom_metric: 5.9866 - val_loss: 6.9650 - val_custom_metric: 7.1472 - lr: 1.5625e-05
# Epoch 56/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.9778 - custom_metric: 5.9778
# Epoch 56: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 27ms/step - loss: 5.9855 - custom_metric: 5.9670 - val_loss: 6.9635 - val_custom_metric: 7.1452 - lr: 1.5625e-05
# Epoch 57/150
# 42/42 [==============================] - ETA: 0s - loss: 5.9829 - custom_metric: 5.9640
# Epoch 57: val_custom_metric did not improve from 7.13722
#
# Epoch 57: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 42/42 [==============================] - 1s 27ms/step - loss: 5.9829 - custom_metric: 5.9640 - val_loss: 6.9870 - val_custom_metric: 7.1700 - lr: 1.5625e-05
# Epoch 58/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9989 - custom_metric: 5.9989
# Epoch 58: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 27ms/step - loss: 5.9666 - custom_metric: 5.9477 - val_loss: 6.9904 - val_custom_metric: 7.1743 - lr: 7.8125e-06
# Epoch 59/150
# 42/42 [==============================] - ETA: 0s - loss: 5.9647 - custom_metric: 5.9455
# Epoch 59: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 27ms/step - loss: 5.9647 - custom_metric: 5.9455 - val_loss: 6.9983 - val_custom_metric: 7.1820 - lr: 7.8125e-06
# Epoch 60/150
# 42/42 [==============================] - ETA: 0s - loss: 5.9609 - custom_metric: 5.9415
# Epoch 60: val_custom_metric did not improve from 7.13722
#
# Epoch 60: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9609 - custom_metric: 5.9415 - val_loss: 7.0067 - val_custom_metric: 7.1907 - lr: 7.8125e-06
# Epoch 61/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9728 - custom_metric: 5.9728
# Epoch 61: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9403 - custom_metric: 5.9212 - val_loss: 7.0756 - val_custom_metric: 7.2644 - lr: 3.9063e-06
# Epoch 62/150
# 42/42 [==============================] - ETA: 0s - loss: 5.9290 - custom_metric: 5.9098
# Epoch 62: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9290 - custom_metric: 5.9098 - val_loss: 7.0854 - val_custom_metric: 7.2751 - lr: 3.9063e-06
# Epoch 63/150
# 42/42 [==============================] - ETA: 0s - loss: 5.9250 - custom_metric: 5.9057
# Epoch 63: val_custom_metric did not improve from 7.13722
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 42/42 [==============================] - 1s 27ms/step - loss: 5.9250 - custom_metric: 5.9057 - val_loss: 7.0757 - val_custom_metric: 7.2640 - lr: 3.9063e-06
# Epoch 64/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.9107 - custom_metric: 5.9107
# Epoch 64: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9171 - custom_metric: 5.8978 - val_loss: 7.1068 - val_custom_metric: 7.2964 - lr: 1.9531e-06
# Epoch 65/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.9057 - custom_metric: 5.9057
# Epoch 65: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9121 - custom_metric: 5.8928 - val_loss: 7.1124 - val_custom_metric: 7.3023 - lr: 1.9531e-06
# Epoch 66/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9434 - custom_metric: 5.9434
# Epoch 66: val_custom_metric did not improve from 7.13722
#
# Epoch 66: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 42/42 [==============================] - 1s 27ms/step - loss: 5.9104 - custom_metric: 5.8910 - val_loss: 7.1131 - val_custom_metric: 7.3028 - lr: 1.9531e-06
# Epoch 67/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.8992 - custom_metric: 5.8992
# Epoch 67: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9053 - custom_metric: 5.8860 - val_loss: 7.1202 - val_custom_metric: 7.3103 - lr: 9.7656e-07
# Epoch 68/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9372 - custom_metric: 5.9372
# Epoch 68: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9042 - custom_metric: 5.8848 - val_loss: 7.1236 - val_custom_metric: 7.3138 - lr: 9.7656e-07
# Epoch 69/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9363 - custom_metric: 5.9363
# Epoch 69: val_custom_metric did not improve from 7.13722
#
# Epoch 69: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9032 - custom_metric: 5.8838 - val_loss: 7.1237 - val_custom_metric: 7.3137 - lr: 9.7656e-07
# Epoch 70/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.8949 - custom_metric: 5.8949
# Epoch 70: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9010 - custom_metric: 5.8816 - val_loss: 7.1284 - val_custom_metric: 7.3186 - lr: 4.8828e-07
# Epoch 71/150
# 42/42 [==============================] - ETA: 0s - loss: 5.9004 - custom_metric: 5.8810
# Epoch 71: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.9004 - custom_metric: 5.8810 - val_loss: 7.1303 - val_custom_metric: 7.3205 - lr: 4.8828e-07
# Epoch 72/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.8938 - custom_metric: 5.8938
# Epoch 72: val_custom_metric did not improve from 7.13722
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 42/42 [==============================] - 1s 27ms/step - loss: 5.8998 - custom_metric: 5.8804 - val_loss: 7.1304 - val_custom_metric: 7.3206 - lr: 4.8828e-07
# Epoch 73/150
# 42/42 [==============================] - ETA: 0s - loss: 5.8988 - custom_metric: 5.8794
# Epoch 73: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.8988 - custom_metric: 5.8794 - val_loss: 7.1328 - val_custom_metric: 7.3231 - lr: 2.4414e-07
# Epoch 74/150
# 42/42 [==============================] - ETA: 0s - loss: 5.8985 - custom_metric: 5.8791
# Epoch 74: val_custom_metric did not improve from 7.13722
# 42/42 [==============================] - 1s 26ms/step - loss: 5.8985 - custom_metric: 5.8791 - val_loss: 7.1335 - val_custom_metric: 7.3238 - lr: 2.4414e-07
# Epoch 74: early stopping

# %%
predictions = model.predict([test_images_ts,X2,my_m_data_test])
myresults['mm'] = {'current':{'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}}

model.load_weights(f'weights/mm_weights_dmv_region_{region}.hdf5')
predictions = model.predict([test_images_ts,X2,my_m_data_test])
myresults['mm']['saved'] = {'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}
# Out:
# 93/93 [==============================] - 1s 5ms/step
# 93/93 [==============================] - 0s 5ms/step

# %% [markdown]
# ## CNN + Micro

# %%
# CNN branch
image_input = Input(shape=(16, 9, 9, 1), name='image_input')
cnn_branch = Conv3D(32, (3, 3, 3), activation='relu', padding='same')(image_input)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Conv3D(64, (3, 3, 3), activation='relu', padding='same')(cnn_branch)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Conv3D(128, (3, 3, 3), activation='relu', padding='same')(cnn_branch)
cnn_branch = BatchNormalization()(cnn_branch)
cnn_branch = MaxPooling3D(pool_size=(2, 2, 2), strides=(2, 2, 2), padding='same')(cnn_branch)  # Add max-pooling
cnn_branch = Flatten()(cnn_branch)
cnn_branch = Dense(64, activation='relu')(cnn_branch)
cnn_branch = Dense(16, activation='relu')(cnn_branch)

# M branch
micro_input = Input(shape=(m_train.shape[1], m_train.shape[2]), name='micro_input') 
m_branch = LSTM(128, return_sequences=True)(m_input)
m_branch = LSTM(128, return_sequences=True)(m_branch)

# Concatenate the outputs of both branches
concatenated = Concatenate()([cnn_branch, m_branch])

# Fully connected layers for the concatenated output
final_output = Dense(128, activation='relu')(concatenated)
final_output = Dense(64, activation='relu')(final_output)
final_output = Dense(1, activation='sigmoid')(final_output)

# Create the model
model = Model(inputs=[image_input, m_input], outputs=final_output)

# Compile the model
model.compile(optimizer='adam', loss=mean_absolute_percentage_error_revise, metrics=[custom_metric])

# Display the model summary
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\cj_dj\anaconda3\envs\school\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\cj_dj\anaconda3\envs\school\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 17
#      14 cnn_branch = Dense(16, activation='relu')(cnn_branch)
#      16 # M branch
# ---> 17 micro_input = Input(shape=(m_train.shape[1], m_train.shape[2]), name='micro_input')
#      18 m_branch = LSTM(128, return_sequences=True)(m_input)
#      19 m_branch = LSTM(128, return_sequences=True)(m_branch)
#
# NameError: name 'm_train' is not defined

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_custom_metric', verbose=1,factor=0.5,patience=3, min_lr=min_lr)
checkpointer = ModelCheckpoint(filepath='weights/cnn_mm_weights_dmv_%s_%d.hdf5'%('region',region), monitor='val_custom_metric',verbose=1,mode='min', save_best_only=True,save_weights_only=True)
earlyStoper = EarlyStopping(monitor='val_custom_metric', min_delta=0, patience=20, verbose=1, mode='min')
hist=model.fit([train_images_ts, m_train_data],y_train,batch_size=64,shuffle=False, epochs=epochs,validation_data=([val_images_ts,nn_val_data],y_val),callbacks=[earlyStoper,checkpointer,reduce_lr],verbose=1)
# Out:
# Epoch 1/150
# 38/42 [==========================>...] - ETA: 0s - loss: 20.7130 - custom_metric: 20.7130
# Epoch 1: val_custom_metric improved from inf to 39.71635, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 2s 17ms/step - loss: 19.8150 - custom_metric: 19.7062 - val_loss: 40.9902 - val_custom_metric: 39.7163 - lr: 0.0010
# Epoch 2/150
# 41/42 [============================>.] - ETA: 0s - loss: 11.3759 - custom_metric: 11.3759
# Epoch 2: val_custom_metric improved from 39.71635 to 37.94505, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 14ms/step - loss: 11.3073 - custom_metric: 11.2671 - val_loss: 39.1845 - val_custom_metric: 37.9450 - lr: 0.0010
# Epoch 3/150
# 38/42 [==========================>...] - ETA: 0s - loss: 9.7760 - custom_metric: 9.7760
# Epoch 3: val_custom_metric improved from 37.94505 to 37.61394, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 9.9222 - custom_metric: 9.9604 - val_loss: 38.8531 - val_custom_metric: 37.6139 - lr: 0.0010
# Epoch 4/150
# 40/42 [===========================>..] - ETA: 0s - loss: 10.0988 - custom_metric: 10.0988
# Epoch 4: val_custom_metric improved from 37.61394 to 35.99549, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 14ms/step - loss: 10.1843 - custom_metric: 10.1690 - val_loss: 37.2079 - val_custom_metric: 35.9955 - lr: 0.0010
# Epoch 5/150
# 41/42 [============================>.] - ETA: 0s - loss: 10.3073 - custom_metric: 10.3073
# Epoch 5: val_custom_metric improved from 35.99549 to 32.59351, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 10.2552 - custom_metric: 10.2247 - val_loss: 33.7339 - val_custom_metric: 32.5935 - lr: 0.0010
# Epoch 6/150
# 41/42 [============================>.] - ETA: 0s - loss: 8.7459 - custom_metric: 8.7459
# Epoch 6: val_custom_metric improved from 32.59351 to 32.36407, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 8.7371 - custom_metric: 8.7320 - val_loss: 33.4932 - val_custom_metric: 32.3641 - lr: 0.0010
# Epoch 7/150
# 40/42 [===========================>..] - ETA: 0s - loss: 8.8735 - custom_metric: 8.8735
# Epoch 7: val_custom_metric improved from 32.36407 to 31.03300, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 8.9398 - custom_metric: 8.9182 - val_loss: 32.1246 - val_custom_metric: 31.0330 - lr: 0.0010
# Epoch 8/150
# 39/42 [==========================>...] - ETA: 0s - loss: 9.7436 - custom_metric: 9.7436
# Epoch 8: val_custom_metric improved from 31.03300 to 29.14425, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 9.7081 - custom_metric: 9.6979 - val_loss: 30.1634 - val_custom_metric: 29.1443 - lr: 0.0010
# Epoch 9/150
# 42/42 [==============================] - ETA: 0s - loss: 9.8889 - custom_metric: 9.8596
# Epoch 9: val_custom_metric improved from 29.14425 to 27.08386, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 14ms/step - loss: 9.8889 - custom_metric: 9.8596 - val_loss: 28.0428 - val_custom_metric: 27.0839 - lr: 0.0010
# Epoch 10/150
# 41/42 [============================>.] - ETA: 0s - loss: 9.3299 - custom_metric: 9.3299
# Epoch 10: val_custom_metric improved from 27.08386 to 24.42031, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 9.3067 - custom_metric: 9.2930 - val_loss: 25.2275 - val_custom_metric: 24.4203 - lr: 0.0010
# Epoch 11/150
# 39/42 [==========================>...] - ETA: 0s - loss: 15.9054 - custom_metric: 15.9054
# Epoch 11: val_custom_metric did not improve from 24.42031
# 42/42 [==============================] - 1s 14ms/step - loss: 15.7432 - custom_metric: 15.7589 - val_loss: 26.3941 - val_custom_metric: 25.6038 - lr: 0.0010
# Epoch 12/150
# 42/42 [==============================] - ETA: 0s - loss: 10.2306 - custom_metric: 10.1960
# Epoch 12: val_custom_metric improved from 24.42031 to 14.96106, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 10.2306 - custom_metric: 10.1960 - val_loss: 15.1280 - val_custom_metric: 14.9611 - lr: 0.0010
# Epoch 13/150
# 42/42 [==============================] - ETA: 0s - loss: 8.8874 - custom_metric: 8.9013
# Epoch 13: val_custom_metric did not improve from 14.96106
# 42/42 [==============================] - 1s 15ms/step - loss: 8.8874 - custom_metric: 8.9013 - val_loss: 16.0212 - val_custom_metric: 15.7729 - lr: 0.0010
# Epoch 14/150
# 41/42 [============================>.] - ETA: 0s - loss: 13.7845 - custom_metric: 13.7845
# Epoch 14: val_custom_metric improved from 14.96106 to 10.80599, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 13.6840 - custom_metric: 13.6251 - val_loss: 10.5595 - val_custom_metric: 10.8060 - lr: 0.0010
# Epoch 15/150
# 40/42 [===========================>..] - ETA: 0s - loss: 9.7689 - custom_metric: 9.7689
# Epoch 15: val_custom_metric improved from 10.80599 to 8.98090, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 9.7531 - custom_metric: 9.7308 - val_loss: 8.6746 - val_custom_metric: 8.9809 - lr: 0.0010
# Epoch 16/150
# 42/42 [==============================] - ETA: 0s - loss: 9.3277 - custom_metric: 9.3691
# Epoch 16: val_custom_metric did not improve from 8.98090
# 42/42 [==============================] - 1s 16ms/step - loss: 9.3277 - custom_metric: 9.3691 - val_loss: 13.0904 - val_custom_metric: 13.0737 - lr: 0.0010
# Epoch 17/150
# 40/42 [===========================>..] - ETA: 0s - loss: 14.7278 - custom_metric: 14.7278
# Epoch 17: val_custom_metric did not improve from 8.98090
# 42/42 [==============================] - 1s 16ms/step - loss: 14.6526 - custom_metric: 14.6307 - val_loss: 12.1558 - val_custom_metric: 12.1978 - lr: 0.0010
# Epoch 18/150
# 41/42 [============================>.] - ETA: 0s - loss: 10.1624 - custom_metric: 10.1624
# Epoch 18: val_custom_metric improved from 8.98090 to 8.72686, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 10.1102 - custom_metric: 10.0796 - val_loss: 8.4372 - val_custom_metric: 8.7269 - lr: 0.0010
# Epoch 19/150
# 41/42 [============================>.] - ETA: 0s - loss: 8.1294 - custom_metric: 8.1294
# Epoch 19: val_custom_metric did not improve from 8.72686
# 42/42 [==============================] - 1s 15ms/step - loss: 8.1521 - custom_metric: 8.1653 - val_loss: 10.2626 - val_custom_metric: 10.4296 - lr: 0.0010
# Epoch 20/150
# 39/42 [==========================>...] - ETA: 0s - loss: 9.5734 - custom_metric: 9.5734
# Epoch 20: val_custom_metric did not improve from 8.72686
# 42/42 [==============================] - 1s 15ms/step - loss: 9.5602 - custom_metric: 9.5358 - val_loss: 12.7247 - val_custom_metric: 12.9191 - lr: 0.0010
# Epoch 21/150
# 41/42 [============================>.] - ETA: 0s - loss: 8.8442 - custom_metric: 8.8442
# Epoch 21: val_custom_metric did not improve from 8.72686
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 42/42 [==============================] - 1s 15ms/step - loss: 8.8566 - custom_metric: 8.8639 - val_loss: 8.7864 - val_custom_metric: 8.9893 - lr: 0.0010
# Epoch 22/150
# 41/42 [============================>.] - ETA: 0s - loss: 8.7627 - custom_metric: 8.7627
# Epoch 22: val_custom_metric improved from 8.72686 to 7.96045, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 8.7466 - custom_metric: 8.7372 - val_loss: 7.6773 - val_custom_metric: 7.9604 - lr: 5.0000e-04
# Epoch 23/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.9072 - custom_metric: 7.9072
# Epoch 23: val_custom_metric improved from 7.96045 to 7.83729, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 7.9044 - custom_metric: 7.9028 - val_loss: 7.5763 - val_custom_metric: 7.8373 - lr: 5.0000e-04
# Epoch 24/150
# 42/42 [==============================] - ETA: 0s - loss: 7.9668 - custom_metric: 7.9607
# Epoch 24: val_custom_metric improved from 7.83729 to 7.80145, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 7.9668 - custom_metric: 7.9607 - val_loss: 7.5480 - val_custom_metric: 7.8015 - lr: 5.0000e-04
# Epoch 25/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.8023 - custom_metric: 7.8023
# Epoch 25: val_custom_metric did not improve from 7.80145
# 42/42 [==============================] - 1s 15ms/step - loss: 7.7977 - custom_metric: 7.7949 - val_loss: 7.7117 - val_custom_metric: 7.9428 - lr: 5.0000e-04
# Epoch 26/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.7865 - custom_metric: 7.7865
# Epoch 26: val_custom_metric did not improve from 7.80145
# 42/42 [==============================] - 1s 15ms/step - loss: 7.7783 - custom_metric: 7.7735 - val_loss: 7.6407 - val_custom_metric: 7.8656 - lr: 5.0000e-04
# Epoch 27/150
# 42/42 [==============================] - ETA: 0s - loss: 7.5807 - custom_metric: 7.5767
# Epoch 27: val_custom_metric did not improve from 7.80145
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 42/42 [==============================] - 1s 15ms/step - loss: 7.5807 - custom_metric: 7.5767 - val_loss: 7.7322 - val_custom_metric: 7.9537 - lr: 5.0000e-04
# Epoch 28/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.6158 - custom_metric: 7.6158
# Epoch 28: val_custom_metric improved from 7.80145 to 7.58610, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 7.6033 - custom_metric: 7.5960 - val_loss: 7.2982 - val_custom_metric: 7.5861 - lr: 2.5000e-04
# Epoch 29/150
# 42/42 [==============================] - ETA: 0s - loss: 7.1662 - custom_metric: 7.1618
# Epoch 29: val_custom_metric improved from 7.58610 to 7.44922, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 7.1662 - custom_metric: 7.1618 - val_loss: 7.1933 - val_custom_metric: 7.4492 - lr: 2.5000e-04
# Epoch 30/150
# 42/42 [==============================] - ETA: 0s - loss: 7.1009 - custom_metric: 7.0952
# Epoch 30: val_custom_metric improved from 7.44922 to 7.43344, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 7.1009 - custom_metric: 7.0952 - val_loss: 7.1682 - val_custom_metric: 7.4334 - lr: 2.5000e-04
# Epoch 31/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.0381 - custom_metric: 7.0381
# Epoch 31: val_custom_metric improved from 7.43344 to 7.42790, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 7.0287 - custom_metric: 7.0232 - val_loss: 7.1608 - val_custom_metric: 7.4279 - lr: 2.5000e-04
# Epoch 32/150
# 41/42 [============================>.] - ETA: 0s - loss: 7.0072 - custom_metric: 7.0072
# Epoch 32: val_custom_metric improved from 7.42790 to 7.36957, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 6.9964 - custom_metric: 6.9901 - val_loss: 7.1368 - val_custom_metric: 7.3696 - lr: 2.5000e-04
# Epoch 33/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.9172 - custom_metric: 6.9172
# Epoch 33: val_custom_metric improved from 7.36957 to 7.34774, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 6.9037 - custom_metric: 6.8958 - val_loss: 7.1156 - val_custom_metric: 7.3477 - lr: 2.5000e-04
# Epoch 34/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.9001 - custom_metric: 6.9001
# Epoch 34: val_custom_metric improved from 7.34774 to 7.30034, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 6.8888 - custom_metric: 6.8822 - val_loss: 7.0565 - val_custom_metric: 7.3003 - lr: 2.5000e-04
# Epoch 35/150
# 42/42 [==============================] - ETA: 0s - loss: 6.8852 - custom_metric: 6.8766
# Epoch 35: val_custom_metric did not improve from 7.30034
# 42/42 [==============================] - 1s 15ms/step - loss: 6.8852 - custom_metric: 6.8766 - val_loss: 7.1196 - val_custom_metric: 7.3449 - lr: 2.5000e-04
# Epoch 36/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.8300 - custom_metric: 6.8300
# Epoch 36: val_custom_metric improved from 7.30034 to 7.22433, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 16ms/step - loss: 6.8166 - custom_metric: 6.8087 - val_loss: 7.0077 - val_custom_metric: 7.2243 - lr: 2.5000e-04
# Epoch 37/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.7684 - custom_metric: 6.7684
# Epoch 37: val_custom_metric did not improve from 7.22433
# 42/42 [==============================] - 1s 15ms/step - loss: 6.7528 - custom_metric: 6.7436 - val_loss: 7.1714 - val_custom_metric: 7.3635 - lr: 2.5000e-04
# Epoch 38/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.7541 - custom_metric: 6.7541
# Epoch 38: val_custom_metric did not improve from 7.22433
# 42/42 [==============================] - 1s 15ms/step - loss: 6.7354 - custom_metric: 6.7244 - val_loss: 7.4614 - val_custom_metric: 7.6408 - lr: 2.5000e-04
# Epoch 39/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.6064 - custom_metric: 6.6064
# Epoch 39: val_custom_metric did not improve from 7.22433
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 42/42 [==============================] - 1s 15ms/step - loss: 6.6619 - custom_metric: 6.6492 - val_loss: 7.3045 - val_custom_metric: 7.4852 - lr: 2.5000e-04
# Epoch 40/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.5829 - custom_metric: 6.5829
# Epoch 40: val_custom_metric did not improve from 7.22433
# 42/42 [==============================] - 1s 15ms/step - loss: 6.5634 - custom_metric: 6.5519 - val_loss: 7.0343 - val_custom_metric: 7.2454 - lr: 1.2500e-04
# Epoch 41/150
# 42/42 [==============================] - ETA: 0s - loss: 6.4547 - custom_metric: 6.4420
# Epoch 41: val_custom_metric did not improve from 7.22433
# 42/42 [==============================] - 1s 15ms/step - loss: 6.4547 - custom_metric: 6.4420 - val_loss: 7.2490 - val_custom_metric: 7.4329 - lr: 1.2500e-04
# Epoch 42/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.3662 - custom_metric: 6.3662
# Epoch 42: val_custom_metric did not improve from 7.22433
#
# Epoch 42: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 42/42 [==============================] - 1s 16ms/step - loss: 6.4159 - custom_metric: 6.4047 - val_loss: 7.5678 - val_custom_metric: 7.7165 - lr: 1.2500e-04
# Epoch 43/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.4247 - custom_metric: 6.4247
# Epoch 43: val_custom_metric did not improve from 7.22433
# 42/42 [==============================] - 1s 15ms/step - loss: 6.4012 - custom_metric: 6.3874 - val_loss: 7.0598 - val_custom_metric: 7.2567 - lr: 6.2500e-05
# Epoch 44/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.3508 - custom_metric: 6.3508
# Epoch 44: val_custom_metric improved from 7.22433 to 7.20748, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 6.3268 - custom_metric: 6.3127 - val_loss: 7.0009 - val_custom_metric: 7.2075 - lr: 6.2500e-05
# Epoch 45/150
# 41/42 [============================>.] - ETA: 0s - loss: 6.2186 - custom_metric: 6.2186
# Epoch 45: val_custom_metric did not improve from 7.20748
# 42/42 [==============================] - 1s 15ms/step - loss: 6.1936 - custom_metric: 6.1790 - val_loss: 7.0319 - val_custom_metric: 7.2179 - lr: 6.2500e-05
# Epoch 46/150
# 38/42 [==========================>...] - ETA: 0s - loss: 6.0965 - custom_metric: 6.0965
# Epoch 46: val_custom_metric improved from 7.20748 to 7.20667, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 15ms/step - loss: 6.1439 - custom_metric: 6.1279 - val_loss: 7.0097 - val_custom_metric: 7.2067 - lr: 6.2500e-05
# Epoch 47/150
# 40/42 [===========================>..] - ETA: 0s - loss: 6.0471 - custom_metric: 6.0471
# Epoch 47: val_custom_metric did not improve from 7.20667
# 42/42 [==============================] - 1s 14ms/step - loss: 6.0830 - custom_metric: 6.0671 - val_loss: 7.0303 - val_custom_metric: 7.2351 - lr: 6.2500e-05
# Epoch 48/150
# 39/42 [==========================>...] - ETA: 0s - loss: 6.0175 - custom_metric: 6.0175
# Epoch 48: val_custom_metric did not improve from 7.20667
# 42/42 [==============================] - 1s 14ms/step - loss: 6.0418 - custom_metric: 6.0258 - val_loss: 7.0417 - val_custom_metric: 7.2369 - lr: 6.2500e-05
# Epoch 49/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9912 - custom_metric: 5.9912
# Epoch 49: val_custom_metric improved from 7.20667 to 7.20134, saving model to taxi-demand-prediction/weights-dmv\cnn_mm_weights_dmv_region_428.hdf5
# 42/42 [==============================] - 1s 14ms/step - loss: 5.9646 - custom_metric: 5.9490 - val_loss: 7.0250 - val_custom_metric: 7.2013 - lr: 6.2500e-05
# Epoch 50/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.9478 - custom_metric: 5.9478
# Epoch 50: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.9210 - custom_metric: 5.9053 - val_loss: 7.0219 - val_custom_metric: 7.2085 - lr: 6.2500e-05
# Epoch 51/150
# 38/42 [==========================>...] - ETA: 0s - loss: 5.8276 - custom_metric: 5.8276
# Epoch 51: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 15ms/step - loss: 5.8733 - custom_metric: 5.8579 - val_loss: 7.0807 - val_custom_metric: 7.2580 - lr: 6.2500e-05
# Epoch 52/150
# 38/42 [==========================>...] - ETA: 0s - loss: 5.8160 - custom_metric: 5.8160
# Epoch 52: val_custom_metric did not improve from 7.20134
#
# Epoch 52: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 42/42 [==============================] - 1s 14ms/step - loss: 5.8553 - custom_metric: 5.8390 - val_loss: 7.0999 - val_custom_metric: 7.3061 - lr: 6.2500e-05
# Epoch 53/150
# 38/42 [==========================>...] - ETA: 0s - loss: 5.7624 - custom_metric: 5.7624
# Epoch 53: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.8089 - custom_metric: 5.7941 - val_loss: 7.0706 - val_custom_metric: 7.2629 - lr: 3.1250e-05
# Epoch 54/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.6865 - custom_metric: 5.6865
# Epoch 54: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.7207 - custom_metric: 5.7043 - val_loss: 7.0698 - val_custom_metric: 7.2492 - lr: 3.1250e-05
# Epoch 55/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.6566 - custom_metric: 5.6566
# Epoch 55: val_custom_metric did not improve from 7.20134
#
# Epoch 55: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 42/42 [==============================] - 1s 14ms/step - loss: 5.6878 - custom_metric: 5.6709 - val_loss: 7.0744 - val_custom_metric: 7.2472 - lr: 3.1250e-05
# Epoch 56/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.6908 - custom_metric: 5.6908
# Epoch 56: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.6614 - custom_metric: 5.6442 - val_loss: 7.0664 - val_custom_metric: 7.2407 - lr: 1.5625e-05
# Epoch 57/150
# 42/42 [==============================] - ETA: 0s - loss: 5.6648 - custom_metric: 5.6471
# Epoch 57: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.6648 - custom_metric: 5.6471 - val_loss: 7.0723 - val_custom_metric: 7.2458 - lr: 1.5625e-05
# Epoch 58/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.6659 - custom_metric: 5.6659
# Epoch 58: val_custom_metric did not improve from 7.20134
#
# Epoch 58: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 42/42 [==============================] - 1s 14ms/step - loss: 5.6362 - custom_metric: 5.6188 - val_loss: 7.0778 - val_custom_metric: 7.2510 - lr: 1.5625e-05
# Epoch 59/150
# 42/42 [==============================] - ETA: 0s - loss: 5.6043 - custom_metric: 5.5869
# Epoch 59: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.6043 - custom_metric: 5.5869 - val_loss: 7.0781 - val_custom_metric: 7.2701 - lr: 7.8125e-06
# Epoch 60/150
# 37/42 [=========================>....] - ETA: 0s - loss: 5.5244 - custom_metric: 5.5244
# Epoch 60: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5789 - custom_metric: 5.5613 - val_loss: 7.0931 - val_custom_metric: 7.2853 - lr: 7.8125e-06
# Epoch 61/150
# 38/42 [==========================>...] - ETA: 0s - loss: 5.5259 - custom_metric: 5.5259
# Epoch 61: val_custom_metric did not improve from 7.20134
#
# Epoch 61: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5598 - custom_metric: 5.5420 - val_loss: 7.0971 - val_custom_metric: 7.2854 - lr: 7.8125e-06
# Epoch 62/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.5752 - custom_metric: 5.5752
# Epoch 62: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5457 - custom_metric: 5.5285 - val_loss: 7.1362 - val_custom_metric: 7.3283 - lr: 3.9063e-06
# Epoch 63/150
# 39/42 [==========================>...] - ETA: 0s - loss: 5.5060 - custom_metric: 5.5060
# Epoch 63: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5282 - custom_metric: 5.5106 - val_loss: 7.1351 - val_custom_metric: 7.3277 - lr: 3.9063e-06
# Epoch 64/150
# 39/42 [==========================>...] - ETA: 0s - loss: 5.5009 - custom_metric: 5.5009
# Epoch 64: val_custom_metric did not improve from 7.20134
#
# Epoch 64: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5224 - custom_metric: 5.5046 - val_loss: 7.1388 - val_custom_metric: 7.3311 - lr: 3.9063e-06
# Epoch 65/150
# 42/42 [==============================] - ETA: 0s - loss: 5.5111 - custom_metric: 5.4934
# Epoch 65: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5111 - custom_metric: 5.4934 - val_loss: 7.1438 - val_custom_metric: 7.3363 - lr: 1.9531e-06
# Epoch 66/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.4789 - custom_metric: 5.4789
# Epoch 66: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5078 - custom_metric: 5.4900 - val_loss: 7.1460 - val_custom_metric: 7.3387 - lr: 1.9531e-06
# Epoch 67/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.4758 - custom_metric: 5.4758
# Epoch 67: val_custom_metric did not improve from 7.20134
#
# Epoch 67: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 42/42 [==============================] - 1s 14ms/step - loss: 5.5044 - custom_metric: 5.4867 - val_loss: 7.1453 - val_custom_metric: 7.3378 - lr: 1.9531e-06
# Epoch 68/150
# 40/42 [===========================>..] - ETA: 0s - loss: 5.4710 - custom_metric: 5.4710
# Epoch 68: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 15ms/step - loss: 5.4995 - custom_metric: 5.4817 - val_loss: 7.1472 - val_custom_metric: 7.3397 - lr: 9.7656e-07
# Epoch 69/150
# 41/42 [============================>.] - ETA: 0s - loss: 5.5284 - custom_metric: 5.5284
# Epoch 69: val_custom_metric did not improve from 7.20134
# 42/42 [==============================] - 1s 15ms/step - loss: 5.4980 - custom_metric: 5.4802 - val_loss: 7.1476 - val_custom_metric: 7.3401 - lr: 9.7656e-07
# Epoch 69: early stopping

# %%
predictions = model.predict([test_images_ts,my_m_data_test])
myresults['cnn_mm'] = {'current':{'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}}

model.load_weights(f'weights/cnn_mm_weights_dmv_region_{region}.hdf5')
predictions = model.predict([test_images_ts,my_m_data_test])
myresults['cnn_mm']['saved'] = {'rmse':rmse(y2,predictions), 'mape':mape(y2,predictions), 'smape':smape(y2,predictions)}
# Out:
# 93/93 [==============================] - 0s 3ms/step
# 93/93 [==============================] - 0s 3ms/step

# %%
for m, v in myresults.items():
    print(m)
    print(v['current'])
    print(v['saved'])
